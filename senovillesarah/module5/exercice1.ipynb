# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


train_data_url = 'https://www.raphaelcousin.com/modules/data-science-practice/module5/exercise/module5_exercise_train.csv'
test_data_url = 'https://www.raphaelcousin.com/modules/data-science-practice/module5/exercise/module5_exercise_test.csv'


def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f"Téléchargé : {file_name}")


download_file(train_data_url, 'module5_exercise_train.csv')
download_file(test_data_url, 'module5_exercise_test.csv')


df_train = pd.read_csv("module5_exercise_train.csv")
df_test = pd.read_csv("module5_exercise_test.csv")


df_train["date"] = pd.to_datetime(df_train["date"])
df_test["date"] = pd.to_datetime(df_test["date"])

print("Taille train :", df_train.shape)
print("Taille test :", df_test.shape)

df_train.head()
# Out:
# Téléchargé : module5_exercise_train.csv
# Téléchargé : module5_exercise_test.csv
# Taille train : (1909, 16)
# Taille test : (365, 15)
#         date weather_condition   humidity  wind_speed  \
# 0 2015-01-08            Cloudy  69.304377  27.74 km/h
# 1 2015-01-09             Sunny  55.955975  21.78 km/h
# 2 2015-01-10             Rainy  62.701614    6.83 m/s
# 3 2015-01-11             Snowy  60.375001    5.79 m/s
# 4 2015-01-12             Snowy        NaN  25.14 km/h
#
#   oil_brent_price_indicator  temperature_station1  temperature_station2  \
# 0                  Moderate              0.369411                   NaN
# 1                  Moderate              2.009903                   NaN
# 2                  Moderate             -2.603544             -2.422001
# 3                  Moderate             -3.789836             -3.974054
# 4                      High             -2.405522             -2.161129
#
#    temperature_station3  temperature_station4  temperature_station5  \
# 0              0.159977              0.118224             -0.444455
# 1              1.617242                   NaN              2.160063
# 2             -3.685819             -2.392354             -1.936704
# 3             -3.217545             -4.397143             -3.375188
# 4             -2.880773             -2.587199                   NaN
#
#    temperature_station6  temperature_station7  temperature_station8  \
# 0              0.313675              0.106192              0.369430
# 1              2.515627              1.867474              1.953165
# 2             -2.950332             -3.074828             -2.698650
# 3             -3.650454             -5.004991             -3.233724
# 4                   NaN                   NaN                   NaN
#
#    temperature_station9  temperature_station10  electricity_demand
# 0              1.279470              -0.384661          273.511353
# 1              1.878233               1.582365          258.827085
# 2             -2.354860              -2.770883          302.535033
# 3             -4.227899                    NaN          296.270989
# 4             -2.790422              -2.033098          323.498090
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['humidity'].plot(kind='hist', bins=20, title='humidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['temperature_station1'].plot(kind='hist', bins=20, title='temperature_station1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['temperature_station2'].plot(kind='hist', bins=20, title='temperature_station2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['temperature_station3'].plot(kind='hist', bins=20, title='temperature_station3')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('weather_condition').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('wind_speed').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('oil_brent_price_indicator').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='humidity', y='temperature_station1', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='temperature_station1', y='temperature_station2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='temperature_station2', y='temperature_station3', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='temperature_station3', y='temperature_station4', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('weather_condition')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='weather_condition', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('wind_speed')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='wind_speed', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('oil_brent_price_indicator')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='oil_brent_price_indicator', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['temperature_station1']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('weather_condition')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='weather_condition', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('temperature_station1')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['humidity'].plot(kind='line', figsize=(8, 4), title='humidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['temperature_station1'].plot(kind='line', figsize=(8, 4), title='temperature_station1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['temperature_station2'].plot(kind='line', figsize=(8, 4), title='temperature_station2')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['temperature_station3'].plot(kind='line', figsize=(8, 4), title='temperature_station3')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['wind_speed'].value_counts()
#     for x_label, grp in _df_19.groupby('weather_condition')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('weather_condition')
# _ = plt.ylabel('wind_speed')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['oil_brent_price_indicator'].value_counts()
#     for x_label, grp in _df_20.groupby('wind_speed')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('wind_speed')
# _ = plt.ylabel('oil_brent_price_indicator')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['weather_condition'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='humidity', y='weather_condition', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['wind_speed'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='humidity', y='wind_speed', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['oil_brent_price_indicator'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='humidity', y='oil_brent_price_indicator', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['weather_condition'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='temperature_station1', y='weather_condition', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['humidity'].plot(kind='hist', bins=20, title='humidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['temperature_station1'].plot(kind='hist', bins=20, title='temperature_station1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['temperature_station2'].plot(kind='hist', bins=20, title='temperature_station2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_29.groupby('weather_condition').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_30.groupby('wind_speed').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('oil_brent_price_indicator').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32.plot(kind='scatter', x='index', y='humidity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33.plot(kind='scatter', x='humidity', y='temperature_station1', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34.plot(kind='scatter', x='temperature_station1', y='temperature_station2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35.plot(kind='scatter', x='temperature_station2', y='temperature_station3', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('weather_condition')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='weather_condition', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_37.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('wind_speed')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='wind_speed', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_38.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('oil_brent_price_indicator')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='oil_brent_price_indicator', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['temperature_station1']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_39.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('weather_condition')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='weather_condition', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('temperature_station1')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['humidity'].plot(kind='line', figsize=(8, 4), title='humidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['temperature_station1'].plot(kind='line', figsize=(8, 4), title='temperature_station1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_43['temperature_station2'].plot(kind='line', figsize=(8, 4), title='temperature_station2')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['wind_speed'].value_counts()
#     for x_label, grp in _df_44.groupby('weather_condition')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('weather_condition')
# _ = plt.ylabel('wind_speed')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['oil_brent_price_indicator'].value_counts()
#     for x_label, grp in _df_45.groupby('wind_speed')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('wind_speed')
# _ = plt.ylabel('oil_brent_price_indicator')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_46['weather_condition'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_46, x='index', y='weather_condition', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_47['wind_speed'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_47, x='index', y='wind_speed', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_48['oil_brent_price_indicator'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_48, x='index', y='oil_brent_price_indicator', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_49['weather_condition'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_49, x='humidity', y='weather_condition', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
def clean_wind_speed(series):
    return (
        series.astype(str)
        .str.replace("km/h", "", regex=False)
        .str.replace("m/s", "", regex=False)
        .str.replace(",", ".", regex=False)
        .str.strip()
        .astype(float)
    )

df_train["wind_speed"] = clean_wind_speed(df_train["wind_speed"])
df_test["wind_speed"] = clean_wind_speed(df_test["wind_speed"])


num_cols = df_train.select_dtypes(include=["float64", "int64"]).columns
for col in num_cols:
    if col != "electricity_demand":
        median_value = df_train[col].median()
        df_train[col] = df_train[col].fillna(median_value)
        df_test[col] = df_test[col].fillna(median_value)

cat_cols = ["weather_condition", "oil_brent_price_indicator"]
for col in cat_cols:
    df_train[col] = df_train[col].fillna("Unknown")
    df_test[col] = df_test[col].fillna("Unknown")


before = df_train.shape[0]
df_train = df_train.drop_duplicates()
after = df_train.shape[0]

# %%
categorical_cols = ["weather_condition", "oil_brent_price_indicator"]


df_train = pd.get_dummies(df_train, columns=categorical_cols, drop_first=True)
df_test = pd.get_dummies(df_test, columns=categorical_cols, drop_first=True)


df_test = df_test.reindex(columns=df_train.columns.drop("electricity_demand"), fill_value=0)

print("Taille train après encodage :", df_train.shape)
print("Taille test après encodage :", df_test.shape)
# Out:
# Taille train après encodage : (1819, 22)
# Taille test après encodage : (365, 21)

# %%
df_train["is_weekend"] = (df_train["date"].dt.dayofweek >= 5).astype(int)
df_test["is_weekend"] = (df_test["date"].dt.dayofweek >= 5).astype(int)


for df in [df_train, df_test]:
    df["month"] = df["date"].dt.month
    df["dayofyear"] = df["date"].dt.dayofyear


    df["dayofyear_sin"] = np.sin(2 * np.pi * df["dayofyear"] / 365)
    df["dayofyear_cos"] = np.cos(2 * np.pi * df["dayofyear"] / 365)

# %%
before = df_train.shape[0]
df_train = df_train[df_train["electricity_demand"] > 0]
after = df_train.shape[0]

# %%
from sklearn.ensemble import RandomForestRegressor


X = df_train.drop(columns=["electricity_demand", "date"])
y = df_train["electricity_demand"]


pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", RandomForestRegressor(
        n_estimators=200,
        random_state=42,
        max_depth=10
    ))
])


tscv = TimeSeriesSplit(n_splits=3)
mse_scores = []

for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    pipeline.fit(X_train, y_train)
    y_val_pred = pipeline.predict(X_val)

    mse = mean_squared_error(y_val, y_val_pred)
    mse_scores.append(mse)
    print(f"Fold {fold+1} MSE: {mse:.2f}")

print("\nMSE moyen :", np.mean(mse_scores))
# Out:
# Fold 1 MSE: 525.58
# Fold 2 MSE: 439.37
# Fold 3 MSE: 458.29
#
# MSE moyen : 474.4138681412331

# %%
final_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    max_depth=10
)

X = df_train.drop(columns=["electricity_demand", "date"])
y = df_train["electricity_demand"]

final_model.fit(X, y)


X_test = df_test.drop(columns=["date"])


y_test_pred = final_model.predict(X_test)

# %%
submission = pd.DataFrame({
    "date": df_test["date"],
    "electricity_demand": y_test_pred
})


submission.to_csv("submissionformodule5.csv", index=False)
