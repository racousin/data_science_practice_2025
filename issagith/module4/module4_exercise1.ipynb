# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Files sources

# %%
import requests

# %%
# URLs of the files
train_datas_url = 'https://www.raphaelcousin.com/modules/data-science-practice/module4/exercise/module4_exercise_train.zip'
test_data_url = 'https://www.raphaelcousin.com/modules/data-science-practice/module4/exercise/Neighborhood_Market_data.csv'

# Function to download a file
def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f'Downloaded {file_name} from {url}')

# Downloading the files
download_file(train_datas_url, 'module4_exercise_train.zip')
download_file(test_data_url, 'Neighborhood_Market_data.csv')
# Out:
# Downloaded module4_exercise_train.zip from https://www.raphaelcousin.com/modules/data-science-practice/module4/exercise/module4_exercise_train.zip
# Downloaded Neighborhood_Market_data.csv from https://www.raphaelcousin.com/modules/data-science-practice/module4/exercise/Neighborhood_Market_data.csv

# %% [markdown]
# #### CityMart

# %%
# !unzip "module4_exercise_train.zip"
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# read "CityMart_data.csv
df_cm = pd.read_csv('CityMart_data.csv')

# %% [markdown]
# #### Greenfield_Grocers

# %%
# read "Greenfield_Grocers_data.csv"
df_gg = pd.read_csv('Greenfield_Grocers_data.csv',sep='|')

# %%
df_gg
# Out:
#     Unnamed: 0          Unnamed: 1 Unnamed: 2        Unnamed: 3  \
# 0          NaN                 NaN        NaN               NaN
# 1          NaN                 NaN        NaN               NaN
# 2    ITEM_CODE          STORE_NAME       MASS  DIMENSION_LENGTH
# 3        P0006  Greenfield_Grocers       5.02             86.68
# 4        P0014  Greenfield_Grocers       9.91             21.67
# ..         ...                 ...        ...               ...
# 399      P1983  Greenfield_Grocers       3.13             37.39
# 400      P1985  Greenfield_Grocers       0.66             30.04
# 401      P1988  Greenfield_Grocers       7.28              7.34
# 402      P1990  Greenfield_Grocers       6.71             73.91
# 403      P1995  Greenfield_Grocers       8.42             83.07
#
#           Unnamed: 4        Unnamed: 5                Unnamed: 6  \
# 0                NaN               NaN                       NaN
# 1                NaN               NaN                       NaN
# 2    DIMENSION_WIDTH  DIMENSION_HEIGHT  DAYS_SINCE_LAST_PURCHASE
# 3              71.64             16.42                        66
# 4              54.91              84.8                        99
# ..               ...               ...                       ...
# 399            74.87             84.11                       168
# 400            15.77             70.62                         5
# 401            89.94             37.33                        92
# 402            10.24             89.64                         9
# 403            19.07             10.84                       248
#
#              Unnamed: 7 Unnamed: 8     Unnamed: 9    Unnamed: 10  Unnamed: 11  \
# 0                   NaN        NaN            NaN            NaN          NaN
# 1                   NaN        NaN            NaN            NaN          NaN
# 2        PACKAGE_VOLUME  STOCK_AGE  QUANTITY_SOLD  LAST_MODIFIED          1.0
# 3    101964.18038400002        450            130     2023-01-06          NaN
# 4    100903.49455999999        827            118     2023-01-14          NaN
# ..                  ...        ...            ...            ...          ...
# 399  235456.63402300002         31            154     2028-06-05          NaN
# 400        33454.869096         76             73     2028-06-07          NaN
# 401  24643.757867999997        770            162     2028-06-10          NaN
# 402        67842.994176        968            115     2028-06-12          NaN
# 403        17172.130716        296             98     2028-06-17          NaN
#
#      Unnamed: 12
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 399          NaN
# 400          NaN
# 401          NaN
# 402          NaN
# 403          NaN
#
# [404 rows x 13 columns]

# %%
df_gg.drop(df_gg.index[0:2], inplace=True)

# %%
df_gg.columns = df_gg.iloc[0].str.lower()
df_gg = df_gg[1:].reset_index(drop=True)  # supprimer la première ligne et réindexer

# %%
df_gg = df_gg.iloc[:,:-2]

# %%
df_gg
# Out:
# 2   item_code          store_name  mass dimension_length dimension_width  \
# 0       P0006  Greenfield_Grocers  5.02            86.68           71.64
# 1       P0014  Greenfield_Grocers  9.91            21.67           54.91
# 2       P0016  Greenfield_Grocers  1.13            60.03           97.39
# 3       P0021  Greenfield_Grocers  0.95            40.36           67.91
# 4       P0028  Greenfield_Grocers  5.24            22.37           61.78
# ..        ...                 ...   ...              ...             ...
# 396     P1983  Greenfield_Grocers  3.13            37.39           74.87
# 397     P1985  Greenfield_Grocers  0.66            30.04           15.77
# 398     P1988  Greenfield_Grocers  7.28             7.34           89.94
# 399     P1990  Greenfield_Grocers  6.71            73.91           10.24
# 400     P1995  Greenfield_Grocers  8.42            83.07           19.07
#
# 2   dimension_height days_since_last_purchase      package_volume stock_age  \
# 0              16.42                       66  101964.18038400002       450
# 1               84.8                       99  100903.49455999999       827
# 2               90.0                      348          526168.953       981
# 3              99.76                      301  273426.95657599997       289
# 4              68.67                       15        94903.217262       423
# ..               ...                      ...                 ...       ...
# 396            84.11                      168  235456.63402300002        31
# 397            70.62                        5        33454.869096        76
# 398            37.33                       92  24643.757867999997       770
# 399            89.64                        9        67842.994176       968
# 400            10.84                      248        17172.130716       296
#
# 2   quantity_sold last_modified
# 0             130    2023-01-06
# 1             118    2023-01-14
# 2             136    2023-01-16
# 3             155    2023-01-21
# 4             177    2023-01-28
# ..            ...           ...
# 396           154    2028-06-05
# 397            73    2028-06-07
# 398           162    2028-06-10
# 399           115    2028-06-12
# 400            98    2028-06-17
#
# [401 rows x 11 columns]

# %% [markdown]
# #### Outlet_data

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\issa\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\issa\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
# read "SuperSaver_Outlet_data.xlsx"
df_ss = pd.read_excel("SuperSaver_Outlet_data.xlsx")

# %% [markdown]
# #### HighStreet_Bazaar

# %%
# read 'HighStreet_Bazaar_data.json'
df_hb = pd.read_json('HighStreet_Bazaar_data.json')

# %% [markdown]
# #### Aggregate

# %% [markdown]
# #### Simple baseline

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import numpy as np

def get_simple_baseline(data, fillna_value=-1, drop_cols=None, k_fold=5, scaler='standard', model='linear', metric='mae', target_col=None, X_data_test=None):
    
    data = data.copy()
    # Handle missing values
    data.fillna(fillna_value, inplace=True)
    if X_data_test is not None:
        X_data_test = X_data_test.copy()
        X_data_test.fillna(fillna_value, inplace=True)
    
    # Drop unwanted columns
    if drop_cols:
        data.drop(drop_cols, axis=1, inplace=True)
        if X_data_test is not None:
            X_data_test.drop(drop_cols, axis=1, inplace=True)

    # Split data into features (X) and target (y)
    y = data[target_col]
    X = data.drop(target_col, axis=1)

    # Feature scaling
    if scaler == 'standard':
        scaler = StandardScaler()
    elif scaler == 'minmax':
        scaler = MinMaxScaler()
    else:
        scaler = None
    
    if scaler:
        X = scaler.fit_transform(X)
        if X_data_test is not None:
            X_data_test = scaler.transform(X_data_test)

    # Initialize the model
    if model == 'linear':
        model = LinearRegression()
    elif model == 'logistic':
        model = LogisticRegression()
    elif model == 'random_forest':
        model = RandomForestClassifier()
    else:
        raise ValueError("Unsupported model type")

    # Initialize cross-validation
    kf = KFold(n_splits=k_fold, shuffle=True, random_state=42)
    scores = []

    # Train and evaluate using k-fold cross-validation
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Train the model
        model.fit(X_train, y_train)
        
        # Make predictions
        y_pred = model.predict(X_test)
        
        # Evaluate using the specified metric
        if metric == 'mae':
            score = mean_absolute_error(y_test, y_pred)
        elif metric == 'accuracy':
            score = accuracy_score(y_test, np.round(y_pred))
        else:
            raise ValueError("Unsupported metric")

        scores.append(score)

    if X_data_test is not None:
        model.fit(X, y)
        return np.mean(scores), model.predict(X_data_test)
    
    # Return the average score
    return np.mean(scores),y_pred

# %%
data = pd.concat(
    [df_gg, df_cm,df_hb,df_ss],
    axis=0,                      # 0 for vertical, 1 for horizontal
    ignore_index=True)

# %%
get_simple_baseline(data, fillna_value=-1, k_fold=5,drop_cols=['item_code','store_name','last_modified'] ,scaler='standard', model='linear', metric='mae', target_col='quantity_sold')
# Out:
# (np.float64(45.298262959615634),
#  array([202.83478343, 183.57375502, 215.17133805, 202.20100204,
#         197.7536343 , 190.15089047, 189.51479604, 231.40747262,
#         191.4914033 , 190.56020574, 208.54286147, 195.23050861,
#         193.32835469, 235.8851397 , 195.52503774, 213.56420424,
#         215.71134858, 195.20558474, 208.76171454, 191.70158859,
#         186.22204309, 196.46572908, 192.28680315, 195.56853182,
#         194.65376496, 196.13763867, 204.29570287, 193.07131764,
#         197.93332867, 201.64147044, 198.23853091, 191.5078964 ,
#         212.7282893 , 189.93788309, 220.20702009, 193.75734565,
#         200.59789218, 200.67674533, 206.93096891, 187.73764011,
#         196.97131403, 202.70030898, 199.39733904, 235.14241891,
#         193.28255939, 198.39294422, 184.91563634, 200.1765796 ,
#         187.61092146, 195.96619618, 223.27337195, 213.17599035,
#         195.40748185, 231.10264069, 180.34183863, 215.12682362,
#         188.21917251, 209.29580194, 217.06864121, 193.57710086,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456, 197.65981456, 197.65981456,
#         197.65981456, 197.65981456]))

# %% [markdown]
# ### API sources

# %%
def get_api(endpoint_url):
    try:
        # Make the GET request to the mock API
        response = requests.get(endpoint_url)

        if response.status_code == 200:
            data = response.json()
            print(data["message"])
            return data['data']
        else:
            print(f"Failed to retrieve volume data. Status code: {response.status_code}")
    
    except Exception as e:
        print(f"An error occurred: {e}")
password =get_api('https://www.raphaelcousin.com/api/exercise/auth') 
password = password['password']
print(password)

prices = get_api(f'https://www.raphaelcousin.com/api/exercise/{password}/prices')
# Out:
# Authentication successful
# RcUZjhdsYLRzwi4
# Volume data retrieved successfully

# %%
df_prices = pd.DataFrame(list(prices.items()), columns=["item_code", "prices"])

# %%
df_prices
# Out:
#      item_code  prices
# 0        P0001   22.14
# 1        P0002   26.91
# 2        P0003   16.90
# 3        P0004    7.04
# 4        P0005   20.84
# ...        ...     ...
# 1995     P1996   25.80
# 1996     P1997   26.05
# 1997     P1998   17.41
# 1998     P1999    7.57
# 1999     P2000   14.42
#
# [2000 rows x 2 columns]

# %% [markdown]
# #### Aggregate

# %%
data1 = pd.merge(data, df_prices, on = 'item_code',how="inner")
#data1 = pd.merge(data, df_prices, left_index=True, right_index=True, how='left')
#data1 = data1.dropna()

# %%
data1.head()
# Out:
#   item_code          store_name  mass dimension_length dimension_width  \
# 0     P0006  Greenfield_Grocers  5.02            86.68           71.64
# 1     P0014  Greenfield_Grocers  9.91            21.67           54.91
# 2     P0016  Greenfield_Grocers  1.13            60.03           97.39
# 3     P0021  Greenfield_Grocers  0.95            40.36           67.91
# 4     P0028  Greenfield_Grocers  5.24            22.37           61.78
#
#   dimension_height days_since_last_purchase      package_volume stock_age  \
# 0            16.42                       66  101964.18038400002       450
# 1             84.8                       99  100903.49455999999       827
# 2             90.0                      348          526168.953       981
# 3            99.76                      301  273426.95657599997       289
# 4            68.67                       15        94903.217262       423
#
#   quantity_sold last_modified  prices
# 0           130    2023-01-06   15.53
# 1           118    2023-01-14   28.94
# 2           136    2023-01-16   15.10
# 3           155    2023-01-21    3.35
# 4           177    2023-01-28   15.06

# %%
get_simple_baseline(data1, fillna_value=-1, drop_cols=['item_code','store_name','last_modified'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='quantity_sold')
#         196.08788664, 247.63470078, 189.78117583, 200.66177231,
#         218.15199124, 195.06404816, 197.13318773, 203.75898169,
#         176.81812757, 183.35428847, 241.41551051, 231.72168542,
#         189.92582648, 198.08191054, 215.15462414, 197.90636902,
#         212.47165265, 236.71755176, 200.22500032, 207.77284356,
#         181.86138099, 175.34070821, 208.89295173, 189.76365014,
#         194.75096802, 198.76897933, 191.60646687, 183.56247089,
#         197.9196993 , 209.00936363, 207.70681134, 208.88898818,
#         182.83874091, 196.37250368, 200.63495632, 210.73517759,
#         202.93589973, 206.02812358, 195.3493878 , 196.42494392,
#         199.59399321, 193.25589464, 193.7936727 , 205.85526635,
#         185.74620815, 197.88462723, 189.45303549, 183.99842945,
#         188.62716204, 194.77319702, 195.23414965, 182.05858716,
#         198.96018335, 198.71050068, 190.54779797, 189.52986093,
#         191.89224313, 189.01128923, 195.06129241, 194.33145076,
#         189.31859098, 208.7554266 , 202.20605808, 188.76160656,
#         223.46749784, 179.92668127, 195.75272135, 198.90256428,
#         187.05224058, 204.2227258 , 195.92557858, 189.12652739,
#         187.93573311, 177.6027118 , 206.56590164, 181.80890449,
#         193.92811721, 208.10241039, 201.68748638, 194.48510163,
#         177.64112452, 205.89367906, 198.80653248, 200.82320021,
#         204.87574202, 180.86779288, 185.30446188, 186.30319257,
#         209.50447462, 195.52224504, 212.7695557 , 192.08430672,
#         201.72589909, 190.47097254, 194.36986348, 189.89478176,
#         190.43255982, 216.13066858, 206.70034616, 201.1112956 ,
#         205.12542469, 205.93209178, 186.76414519, 181.09826919,
#         198.3263735 , 197.86542087, 196.36732485, 187.22509781,
#         194.3122444 , 206.14336174, 201.39939099, 194.69637159,
#         210.9257452 , 190.20208351, 217.68638368, 215.20876333,
#         184.90112834, 183.76795314, 179.92668127, 188.01255854,
#         210.44558622, 192.94859289, 206.73875887, 206.22018717,
#         198.1343099 , 197.84621451]))

# %% [markdown]
# ### Scrapping sources

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\issa\anaconda3\lib\site-packages (4.38.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\issa\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\issa\anaconda3\lib\site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\issa\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in c:\users\issa\anaconda3\lib\site-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\issa\anaconda3\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\issa\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\issa\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\issa\anaconda3\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\issa\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\issa\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\issa\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver (e.g., Chrome)
driver = webdriver.Chrome()  # Make sure ChromeDriver is installed
# driver = webdriver.Firefox()
# driver = webdriver.Edge()
# driver = webdriver.Safari()

# Open the URL
url = 'https://www.raphaelcousin.com/module4/scrapable-data'
driver.get(url)

# Wait for the page to fully load (increase time if needed)
time.sleep(5)

# Get the fully rendered page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Initialize lists to store scraped data
exercise_data = []

# Find both tables
tables = soup.find_all('table')

# Close the Selenium WebDriver
driver.quit()

# Scrape the second table (Exercise Data)
course_table = tables[1]

course_table = tables[1]
for row in course_table.find('tbody').find_all('tr'):
    cols = row.find_all('td')
    x = [col.get_text(strip=True) for col in cols]    
    exercise_data.append(x)

print(exercise_data)
# Construire le DataFrame avec toutes les colonnes
# Out:
# [['P0001', '2', '972', '1728581'], ['P0002', '3', '260', '1728578'], ['P0003', '2', '285', '1728483'], ['P0004', '5', '512', '1728520'], ['P0005', '3', '85', '1728575'], ['P0006', '1', '849', '1728545'], ['P0007', '3', '429', '1728506'], ['P0008', '5', '580', '1728546'], ['P0009', '5', '30', '1728574'], ['P0010', '2', '709', '1728528'], ['P0011', '2', '602', '1728523'], ['P0012', '4', '439', '1728495'], ['P0013', '3', '984', '1728542'], ['P0014', '4', '348', '1728516'], ['P0015', '5', '894', '1728518'], ['P0016', '2', '411', '1728483'], ['P0017', '2', '527', '1728526'], ['P0018', '2', '309', '1728543'], ['P0019', '1', '948', '1728550'], ['P0020', '5', '395', '1728531'], ['P0021', '2', '787', '1728522'], ['P0022', '5', '337', '1728575'], ['P0023', '2', '673', '1728555'], ['P0024', '3', '436', '1728573'], ['P0025', '5', '703', '1728516'], ['P0026', '4',
# %%
# Convert the lists to pandas DataFrames
df_exercise = pd.DataFrame(exercise_data)
df_exercise
df_exercise.rename(columns={0: "item_code",1:"1",2:"2",3:"3"}, inplace=True)
df_exercise = df_exercise.astype({"1":float,"2":float,"3":float})

# %%
df_exercise
# Out:
#      item_code    1      2          3
# 0        P0001  2.0  972.0  1728581.0
# 1        P0002  3.0  260.0  1728578.0
# 2        P0003  2.0  285.0  1728483.0
# 3        P0004  5.0  512.0  1728520.0
# 4        P0005  3.0   85.0  1728575.0
# ...        ...  ...    ...        ...
# 1995     P1996  5.0  512.0  1728489.0
# 1996     P1997  2.0  989.0  1728567.0
# 1997     P1998  2.0  440.0  1728565.0
# 1998     P1999  4.0   37.0  1728487.0
# 1999     P2000  4.0  701.0  1728509.0
#
# [2000 rows x 4 columns]

# %% [markdown]
# #### Aggregate

# %%
data2 = pd.merge(data1, df_exercise, on='item_code',  how='inner')

# %%
data2
# Out:
#      item_code          store_name  mass dimension_length dimension_width  \
# 0        P0006  Greenfield_Grocers  5.02            86.68           71.64
# 1        P0014  Greenfield_Grocers  9.91            21.67           54.91
# 2        P0016  Greenfield_Grocers  1.13            60.03           97.39
# 3        P0021  Greenfield_Grocers  0.95            40.36           67.91
# 4        P0028  Greenfield_Grocers  5.24            22.37           61.78
# ...        ...                 ...   ...              ...             ...
# 1586     P1976                 NaN   NaN              NaN             NaN
# 1587     P1980                 NaN   NaN              NaN             NaN
# 1588     P1986                 NaN   NaN              NaN             NaN
# 1589     P1993                 NaN   NaN              NaN             NaN
# 1590     P2000                 NaN   NaN              NaN             NaN
#
#      dimension_height days_since_last_purchase      package_volume stock_age  \
# 0               16.42                       66  101964.18038400002       450
# 1                84.8                       99  100903.49455999999       827
# 2                90.0                      348          526168.953       981
# 3               99.76                      301  273426.95657599997       289
# 4               68.67                       15        94903.217262       423
# ...               ...                      ...                 ...       ...
# 1586              NaN                      NaN                 NaN       NaN
# 1587              NaN                      NaN                 NaN       NaN
# 1588              NaN                      NaN                 NaN       NaN
# 1589              NaN                      NaN                 NaN       NaN
# 1590              NaN                      NaN                 NaN       NaN
#
#      quantity_sold last_modified  prices    1      2          3
# 0              130    2023-01-06   15.53  1.0  849.0  1728545.0
# 1              118    2023-01-14   28.94  4.0  348.0  1728516.0
# 2              136    2023-01-16   15.10  2.0  411.0  1728483.0
# 3              155    2023-01-21    3.35  2.0  787.0  1728522.0
# 4              177    2023-01-28   15.06  4.0  922.0  1728548.0
# ...            ...           ...     ...  ...    ...        ...
# 1586           236           NaN   18.69  5.0  574.0  1728536.0
# 1587           192           NaN   17.20  4.0  624.0  1728493.0
# 1588           193           NaN   20.91  2.0  818.0  1728526.0
# item_code
# P0002                 72.02                       344   174261.666176
# P0004                 42.46                       189   141651.425916
# P0005                  5.12                       183    16816.375296
# P0010                 74.41                       208   285543.225828
# P0013                 23.24                       114    76725.649196
# ...                     ...                       ...             ...
# P1972                 95.67                       296   123008.113881
# P1977                 66.30                       171   362873.902560
# P1991                 52.14                        50   365334.635424
# P1997                 41.11                       336    15828.788850
# P1999                 73.20                       190   294133.601520
#
#            stock_age last_modified
# item_code
# P0002            287    2023-01-02
# P0004            387    2023-01-04
# P0005            382    2023-01-05
# P0010            656    2023-01-10
# P0013            755    2023-01-13
# ...              ...           ...
# P1972            411    2028-05-25
# P1977            702    2028-05-30
# P1991            190    2028-06-13
# P1997            177    2028-06-19
# P1999            806    2028-06-21
#
# [409 rows x 9 columns]

# %%
#df_StoreN = pd.merge(df_StoreN, df_prices, left_index=True, right_index=True, how='left')
#df_StoreN = pd.merge(df_StoreN, df_exercise, left_index=True, right_index=True, how='left')
df_StoreN = pd.merge(df_StoreN, df_prices, on = 'item_code', how='inner')
df_StoreN = pd.merge(df_StoreN, df_exercise, on ='item_code', how='inner')

# %%
df_StoreN.columns
# Out:
# Index(['item_code', 'store_name', 'mass', 'dimension_length',
#        'dimension_width', 'dimension_height', 'days_since_last_purchase',
#        'package_volume', 'stock_age', 'last_modified', 'prices', '1', '2',
#        '3'],
#       dtype='object')

# %%
df_StoreN
# Out:
#     item_code           store_name  mass  dimension_length  dimension_width  \
# 0       P0002  Neighborhood_Market  5.51             51.79            46.72
# 1       P0004  Neighborhood_Market  3.97             84.63            39.42
# 2       P0005  Neighborhood_Market  5.99             39.33            83.51
# 3       P0010  Neighborhood_Market  4.10             77.43            49.56
# 4       P0013  Neighborhood_Market  6.96             95.39            34.61
# ..        ...                  ...   ...               ...              ...
# 404     P1972  Neighborhood_Market  5.68             17.89            71.87
# 405     P1977  Neighborhood_Market  1.53             84.32            64.91
# 406     P1991  Neighborhood_Market  7.79             84.46            82.96
# 407     P1997  Neighborhood_Market  8.91             66.50             5.79
# 408     P1999  Neighborhood_Market  2.03             66.77            60.18
#
#      dimension_height  days_since_last_purchase  package_volume  stock_age  \
# 0               72.02                       344   174261.666176        287
# 1               42.46                       189   141651.425916        387
# 2                5.12                       183    16816.375296        382
# 3               74.41                       208   285543.225828        656
# 4               23.24                       114    76725.649196        755
# ..                ...                       ...             ...        ...
# 404             95.67                       296   123008.113881        411
# 405             66.30                       171   362873.902560        702
# 406             52.14                        50   365334.635424        190
# 407             41.11                       336    15828.788850        177
# 408             73.20                       190   294133.601520        806
#
#     last_modified  prices    1      2          3
# 0      2023-01-02   26.91  3.0  260.0  1728578.0
# 1      2023-01-04    7.04  5.0  512.0  1728520.0
# 2      2023-01-05   20.84  3.0   85.0  1728575.0
# 3      2023-01-10   10.00  2.0  709.0  1728528.0
# 4      2023-01-13   12.98  3.0  984.0  1728542.0
# ..            ...     ...  ...    ...        ...
# 404    2028-05-25   15.88  2.0  854.0  1728535.0
